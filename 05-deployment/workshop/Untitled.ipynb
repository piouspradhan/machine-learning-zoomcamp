# %% [markdown]
# *Commands Used*
# - pip install jupyter
# - jupyter nbconvert --to=script workshop-uv-fastapi.ipynb // Convert notebook to python script
# - pip install fastapi uvicorn
# - uvicorn ping:app --host 0.0.0.0 --port 9696 --reload
# - pip install uv
# - uv init
# - uv add scikit-learn fastapi uvicorn
# - uv add --dev requests
